# %%
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-88e7f246-d987-45db-90e8-e8347da7ae63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88e7f246-d987-45db-90e8-e8347da7ae63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Salaries.csv')
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()                                       ##Reading first 5 rows
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()                                            ##Reading last 5 rows
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.columns                                              ##Column names
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes                                               ##Data types
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.tail(10)                                               ##Last 10 rows
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.head(10)                                                   ##First 10 rows
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.describe()                                                ##descriptive statistics
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
df.mode()
# Out:
#    rank discipline  phd  service     sex   salary
# 0  Prof          B  4.0      3.0  Female  92000.0
# 1   NaN        NaN  NaN      NaN    Male      NaN

# %%
df.quantile()
# Out:
# phd            18.5
# service        14.5
# salary     104671.0
# Name: 0.5, dtype: float64

# %%
df.quantile(0.25)
# Out:
# phd           10.25
# service        5.25
# salary     88612.50
# Name: 0.25, dtype: float64

# %%
df.shape
# Out:
# (78, 6)

# %%
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df_50=df.head(50)

# %%
df_50.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.salary                                       ##Selecting Columns
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df[df['rank']=='AssocProf']                                 ##Reading data for particular value
# Out:
#          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 41  AssocProf          A   13        8  Female   74830
# 47  AssocProf          B   11       11  Female  103613
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 64  AssocProf          A   26       24  Female   73300
# 71  AssocProf          B   12        9  Female   71065
# 74  AssocProf          B   19        6  Female  104542

# %%
df[(df['rank']=='AssocProf')&(df['discipline']=='A')]
# Out:
#          rank discipline  phd  service     sex  salary
# 6   AssocProf          A   20       17    Male   81285
# 41  AssocProf          A   13        8  Female   74830
# 54  AssocProf          A   25       22  Female   62884
# 56  AssocProf          A   10        8  Female   77500
# 64  AssocProf          A   26       24  Female   73300

# %%
df.phd.describe()                                               ##Descriptive Statistics for particular value
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df['phd'].describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df['phd'].count()
# Out:
# 78

# %%
df['phd'].mean()
# Out:
# 19.705128205128204

# %%
df.groupby(['rank']).mean()                                 ##groupby rank and obtaining its mean
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
grouped=df.groupby('rank')

# %%
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df[df['salary']>120000]                               ##Reading data whose salary is >120000
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df.iloc[1:3,0:4]                                        ##iloc function for selecting particular rows and columns
# Out:
#    rank discipline  phd  service
# 1  Prof          A   12        6
# 2  Prof          A   23       20

# %%
df.iloc[0:10,1:4]
# Out:
#   discipline  phd  service
# 0          B   56       49
# 1          A   12        6
# 2          A   23       20
# 3          A   40       31
# 4          B   20       18
# 5          A   20       20
# 6          A   20       17
# 7          A   18       18
# 8          A   29       19
# 9          A   51       51

# %%
df.iloc[0:2,:]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[:,1:4]
# Out:
#    discipline  phd  service
# 0           B   56       49
# 1           A   12        6
# 2           A   23       20
# 3           A   40       31
# 4           B   20       18
# ..        ...  ...      ...
# 73          B   18       10
# 74          B   19        6
# 75          B   17       17
# 76          A   28       14
# 77          A   23       15
#
# [78 rows x 3 columns]

# %%
df.iloc[[5,9,10,12,20],:]
# Out:
#         rank discipline  phd  service   sex  salary
# 5       Prof          A   20       20  Male  122400
# 9       Prof          A   51       51  Male   57800
# 10      Prof          B   39       33  Male  128250
# 12  AsstProf          B    1        0  Male   88000
# 20  AsstProf          B    4        4  Male   92000

# %%
df.iloc[:,[0,3,4,5]]
# Out:
#          rank  service     sex  salary
# 0        Prof       49    Male  186960
# 1        Prof        6    Male   93000
# 2        Prof       20    Male  110515
# 3        Prof       31    Male  131205
# 4        Prof       18    Male  104800
# ..        ...      ...     ...     ...
# 73       Prof       10  Female  105450
# 74  AssocProf        6  Female  104542
# 75       Prof       17  Female  124312
# 76       Prof       14  Female  109954
# 77       Prof       15  Female  109646
#
# [78 rows x 4 columns]

# %%
df.iloc[[5,6,9,10,12,15,21],[0,3,4,5]]
# Out:
#          rank  service   sex  salary
# 5        Prof       20  Male  122400
# 6   AssocProf       17  Male   81285
# 9        Prof       51  Male   57800
# 10       Prof       33  Male  128250
# 12   AsstProf        0  Male   88000
# 15       Prof        3  Male  150480
# 21       Prof       30  Male  103106

# %%
df.iloc[25:30,:]
# Out:
#         rank discipline  phd  service   sex  salary
# 25      Prof          B   35       31  Male   99418
# 26      Prof          A   38       19  Male  148750
# 27      Prof          A   45       43  Male  155865
# 28  AsstProf          B    7        2  Male   91300
# 29      Prof          B   21       20  Male  123683

# %%
df.iloc[25:31,1:5]
# Out:
#    discipline  phd  service   sex
# 25          B   35       31  Male
# 26          A   38       19  Male
# 27          A   45       43  Male
# 28          B    7        2  Male
# 29          B   21       20  Male
# 30          B    9        7  Male

# %%
df[['salary','service']].min()
# Out:
# salary     57800
# service        0
# dtype: int64

# %%
df['rank'].unique()                                    ##unique values from rank column
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
print('The salary of first 5 entries are:',df['salary'].head())         ##Print statements
# Out:
# The salary of first 5 entries are: 0    186960
# 1     93000
# 2    110515
# 3    131205
# 4    104800
# Name: salary, dtype: int64

# %%
print(df[['salary','phd','service']].head())
# Out:
#    salary  phd  service
# 0  186960   56       49
# 1   93000   12        6
# 2  110515   23       20
# 3  131205   40       31
# 4  104800   20       18

# %%
print(df[['salary','phd','service','sex']].tail())
# Out:
#     salary  phd  service     sex
# 73  105450   18       10  Female
# 74  104542   19        6  Female
# 75  124312   17       17  Female
# 76  109954   28       14  Female
# 77  109646   23       15  Female

# %%
print('the maximum salary of Assoprof is Rs',df[df['rank']=='AssocProf']['salary'].max())
# Out:
# the maximum salary of Assoprof is Rs 119800

# %%
print('the minimum years of service for Prof is',df[df['rank']=='Prof']['service'].min())
# Out:
# the minimum years of service for Prof is 0

# %%
print('The count of Male AsstProf is',df[df['sex']=='Male'][df['rank']=='AsstProf'].count())
# Out:
# The count of Male AsstProf is rank          8
# discipline    8
# phd           8
# service       8
# sex           8
# salary        8
# dtype: int64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
print('The count of Male AsstProf is',df[df['sex']=='Male'][df['rank']=='AsstProf']['discipline'].count())
# Out:
# The count of Male AsstProf is 8
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
print('The count of Male in Dataset for service is',df[df['sex']=='Male']['service'].count())
# Out:
# The count of Male in Dataset for service is 39
